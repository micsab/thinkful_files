# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
# %matplotlib inline

# %%
edges = pd.read_csv('disease_gene.csv', sep=" ")
tuples = [(x[0],x[1],{"weight":x[2]}) for x in edges.values]
diseases=nx.Graph()
diseases.add_edges_from(tuples)
edges.head()
# Out:
#    #Entrez_id1  Entrez_id2  Weight
# 0            2         351       1
# 1            2         348       1
# 2            2        5664       1
# 3            2         323       1
# 4            2        4846       1

# %%
# Loading the list of node characteristics 
nodes = pd.read_table('supplementary_tableS3.txt',header=0)

nodes=nodes[['Entrez ID', 'Symbol', 'Disorder class', 'Implicated diseases (Disease ID) [comma-deliminated]']]
print(nodes.head())

# Adding attributes to the nodes in the graph
for node in nodes['Entrez ID']:
    if node in diseases.nodes():
        diseases.node[node]['symbol'] = nodes.loc[nodes['Entrez ID']==node, 'Symbol'].values[0]
        diseases.node[node]['class'] = nodes.loc[nodes['Entrez ID']==node, 'Disorder class'].values[0]
        diseases.node[node]['diseases'] = nodes.loc[nodes['Entrez ID']==node, 'Implicated diseases (Disease ID) [comma-deliminated]'].values[0]
        
print(diseases.node[348])
# Out:
#    Entrez ID    Symbol Disorder class  \
# 0          2       A2M   Neurological
# 1         10      NAT2      Metabolic
# 2         12  SERPINA3           Grey
# 3         15     AANAT    Psychiatric
# 4         18      ABAT      Metabolic
#
#   Implicated diseases (Disease ID) [comma-deliminated]
# 0                             Alzheimer_disease (98)
# 1                            Slow_acetylation (1403)
# 2  Alpha-1-antichymotrypsin_deficiency (87), Cere...
# 3                 Delayed_sleep_phase_syndrome (411)
# 4                 GABA-transaminase_deficiency (564)
# {'symbol': 'APOE', 'class': 'Grey', 'diseases': 'Alzheimer_disease (98), Hyperlipoproteinemia (737), Myocardial_infarction (1054), Sea-blue_histiocyte_disease (1366)'}

# %%
plt.rcParams['figure.figsize']=[24,24]
nx.draw_networkx(diseases,
                pos=nx.spring_layout(diseases,weight='weights'),
                node_color='lightblue',
                edge_color='gray',
                node_size=100,
                with_labels=False,
                alpha=.8
                )

plt.axis('off')
plt.show()

# %%
numberofnodes=diseases.number_of_nodes()
nodedegrees=dict(diseases.degree())
nodedegrees=list(nodedegrees.values())
av_degree=np.mean(nodedegrees)
med_degree=np.median(nodedegrees)
clustering=list(nx.clustering(diseases).values())
betweenness_cent=list(nx.betweenness_centrality(diseases).values())
componentsizes=[len(c) for c in sorted(nx.connected_components(diseases), key=len, reverse=True)]

print('This graph has {} nodes and {} edges.'.format(diseases.number_of_nodes(), diseases.number_of_edges()))
print('The median degree is {} and the mean degree is {}.'.format(med_degree, av_degree))
print('There are {} connected components within the graph.'.format(nx.number_connected_components(diseases)))

plt.rcParams['figure.figsize']=[6,4]

plt.hist(nodedegrees)
plt.title('Degrees')
plt.show()

plt.hist(clustering)
plt.title('Clustering')
plt.show()

plt.hist(betweenness_cent)
plt.title('Betweenness')
plt.show()

plt.hist(componentsizes)
plt.title('Connected components')
plt.show()
# Out:
# This graph has 1378 nodes and 7491 edges.
# The median degree is 6.0 and the mean degree is 10.872278664731494.
# There are 141 connected components within the graph.

# %%
nodedegrees=dict(diseases.degree())


# Pulling our node-level statistics together into a dataframe
graph_stats=pd.DataFrame({'node':list(nodedegrees.keys()),
                         'degree':list(nodedegrees.values()),
                         'clustering':list(nx.clustering(diseases).values()),
                         'betweenness_cent':list(nx.betweenness_centrality(diseases).values())
                         })

# Assigning each node to a component by number
graph_stats['component']=None

# Sorting the components by size so that the largest component will be numbered 0
components=sorted(nx.connected_components(diseases), key=len, reverse=True)
for i,component in enumerate(components):
    graph_stats.loc[graph_stats['node'].isin(list(component)),'component']=i
    
print(graph_stats.head(15))
# Out:
#      node  degree  clustering  betweenness_cent  component
# 0       2      11    1.000000          0.000000          0
# 1     351      24    0.336957          0.036849          0
# 2     348      20    0.478947          0.003949          0
# 3    5664      11    1.000000          0.000000          0
# 4     323      11    1.000000          0.000000          0
# 5    4846      22    0.489177          0.005236          0
# 6    5328      11    1.000000          0.000000          0
# 7    1636      48    0.375887          0.068634          0
# 8    4353      11    1.000000          0.000000          0
# 9   22976      11    1.000000          0.000000          0
# 10    642      11    1.000000          0.000000          0
# 11   5663      16    0.541667          0.020477          0
# 12     19       7    0.476190          0.005680          0
# 13   1471       1    0.000000          0.000000          0
# 14   4205       5    1.000000          0.000000          0

# %%
# Logging these two for easier relationship viewing.
graph_stats['log_between']=np.log(graph_stats['betweenness_cent']+.001)
graph_stats['log_degree']=np.log(graph_stats['degree']+1)

g = sns.pairplot(graph_stats,
                 vars=['log_between','clustering','log_degree'],
                 kind='scatter',
                plot_kws={'alpha':.3})
plt.show()

# %%
disease_stats=pd.merge(graph_stats,nodes,left_on='node',right_on='Entrez ID',how='outer')

print(disease_stats.head())
# Out:
#      node  degree  clustering  betweenness_cent  component  log_between  \
# 0     2.0    11.0    1.000000          0.000000        0.0    -6.907755
# 1   351.0    24.0    0.336957          0.036849        0.0    -3.274150
# 2   348.0    20.0    0.478947          0.003949        0.0    -5.308508
# 3  5664.0    11.0    1.000000          0.000000        0.0    -6.907755
# 4   323.0    11.0    1.000000          0.000000        0.0    -6.907755
#
#    log_degree  Entrez ID Symbol Disorder class  \
# 0    2.484907          2    A2M   Neurological
# 1    3.218876        351    APP           Grey
# 2    3.044522        348   APOE           Grey
# 3    2.484907       5664  PSEN2   Neurological
# 4    2.484907        323  APBB2   Neurological
#
#   Implicated diseases (Disease ID) [comma-deliminated]
# 0                             Alzheimer_disease (98)
# 1  Alzheimer_disease (98), Amyloidosis (103), Sch...
# 2  Alzheimer_disease (98), Hyperlipoproteinemia (...
# 3                             Alzheimer_disease (98)
# 4                             Alzheimer_disease (98)

# %%
sns.swarmplot(x='degree', y='Disorder class', data=disease_stats,alpha=.3)
plt.title('Degree by class')
plt.show()

sns.swarmplot(x='betweenness_cent', y='Disorder class', data=disease_stats,alpha=.3)
plt.title('Betweenness Centrality by class')
plt.show()

sns.swarmplot(x='clustering', y='Disorder class', data=disease_stats,alpha=.3)
plt.title('Clustering by class')
plt.show()

# %%
print('The number of nodes in each class:')
nodesbyclass = disease_stats.groupby(by='Disorder class')['component'].count()
print(nodesbyclass)

print('\nThe number of connected componenets that members of each class belong to.')
componentsbyclass=disease_stats.groupby(by='Disorder class')['component'].apply(lambda x: len(set(x)))
print(componentsbyclass)

# A class with more nodes has more opportunities to belong to multiple components, so we'll divide by number of nodes.
print('\nNumber of components by class normalized by number of nodes.')
print(componentsbyclass/nodesbyclass)
# Out:
# The number of nodes in each class:
# Disorder class
# Bone                           19
# Cancer                        144
# Cardiovascular                 50
# Connective_tissue_disorder     20
# Dermatological                 52
# Developmental                  19
# Ear,Nose,Throat                27
# Endocrine                      51
# Gastrointestinal               15
# Grey                          268
# Hematological                  92
# Immunological                  58
# Metabolic                     134
# Muscular                       38
# Neurological                  149
# Nutritional                    18
# Ophthamological                85
# Psychiatric                    13
# Renal                          29
# Respiratory                    12
# Skeletal                       20
# Unclassified                    0
# multiple                       65
# Name: component, dtype: int64
#
# The number of connected componenets that members of each class belong to.
# Disorder class
# Bone                           11
# Cancer                         20
# Cardiovascular                 10
# Connective_tissue_disorder     10
# Dermatological                 17
# Developmental                  21
# Ear,Nose,Throat                 2
# Endocrine                      22
# Gastrointestinal               14
# Grey                           72
# Hematological                  33
# Immunological                  35
# Metabolic                     144
# Muscular                       14
# Neurological                   50
# Nutritional                     2
# Ophthamological                19
# Psychiatric                     9
# Renal                          21
# Respiratory                     3
# Skeletal                       18
# Unclassified                   13
# multiple                       54
# Name: component, dtype: int64
#
# Number of components by class normalized by number of nodes.
# Disorder class
# Bone                          0.578947
# Cancer                        0.138889
# Cardiovascular                0.200000
# Connective_tissue_disorder    0.500000
# Dermatological                0.326923
# Developmental                 1.105263
# Ear,Nose,Throat               0.074074
# Endocrine                     0.431373
# Gastrointestinal              0.933333
# Grey                          0.268657
# Hematological                 0.358696
# Immunological                 0.603448
# Metabolic                     1.074627
# Muscular                      0.368421
# Neurological                  0.335570
# Nutritional                   0.111111
# Ophthamological               0.223529
# Psychiatric                   0.692308
# Renal                         0.724138
# Respiratory                   0.250000
# Skeletal                      0.900000
# Unclassified                       inf
# multiple                      0.830769
# Name: component, dtype: float64

# %%
# Count of nodes in components
nodesbycomponent=disease_stats.groupby(by='component')['Disorder class'].count()

# The number of classes that members of each component belong to.
classesbycomponent=disease_stats.groupby(by='component')['Disorder class'].apply(lambda x: len(set(x)))

sns.countplot(classesbycomponent)
plt.xlabel('Number of disorder classes in component')
plt.show()

# Plotting number of classes in a component by size of component
fig = plt.figure()
ax = plt.gca()
ax.scatter(classesbycomponent, nodesbycomponent)
# Using log scales because of outliers
ax.set_yscale('log')
ax.set_xscale('log')
plt.xlabel('Number of disease classes')
plt.ylabel('Number of nodes')
plt.show()

# List of homogenous components that contain only one class
homogenous=classesbycomponent[classesbycomponent==1].index

# The number of nodes and class of homogenous component:
componentclasses=disease_stats[disease_stats['component']
                               .isin(list(homogenous))].groupby(by='component')['Disorder class'].apply(lambda x: [list(set(x))[0],len(x)])

print(componentclasses)
# Out:
# component
# 3.0                      [Metabolic, 13]
# 5.0                      [Metabolic, 10]
# 6.0                  [Hematological, 10]
# 7.0                       [Metabolic, 9]
# 8.0                       [Metabolic, 9]
# 11.0                       [multiple, 7]
# 13.0                  [Immunological, 6]
# 14.0                   [Neurological, 6]
# 17.0                    [Respiratory, 5]
# 18.0                       [multiple, 5]
# 20.0                   [Neurological, 5]
# 23.0                   [Neurological, 5]
# 26.0                      [Metabolic, 4]
# 28.0                 [Dermatological, 4]
# 31.0                  [Immunological, 4]
# 33.0                      [Metabolic, 4]
# 35.0                 [Dermatological, 4]
# 36.0                           [Bone, 4]
# 37.0                      [Metabolic, 4]
# 38.0               [Gastrointestinal, 4]
# 39.0                          [Renal, 4]
# 41.0                      [Metabolic, 3]
# 42.0                          [Renal, 3]
# 46.0     [Connective_tissue_disorder, 3]
# 47.0                          [Renal, 3]
# 48.0                [Ophthamological, 3]
# 51.0                          [Renal, 3]
# 52.0                       [Muscular, 3]
# 53.0                           [Grey, 3]
# 54.0                      [Metabolic, 3]
#                       ...
# 108.0                     [Endocrine, 2]
# 109.0                     [Metabolic, 2]
# 110.0                      [multiple, 2]
# 111.0                      [multiple, 2]
# 112.0                     [Metabolic, 2]
# 113.0                         [Renal, 2]
# 114.0                 [Hematological, 2]
# 115.0                     [Metabolic, 2]
# 116.0                      [multiple, 2]
# 117.0                     [Metabolic, 2]
# 118.0                 [Hematological, 2]
# 119.0              [Gastrointestinal, 2]
# 120.0                     [Endocrine, 2]
# 121.0               [Ophthamological, 2]
# 125.0                     [Endocrine, 2]
# 126.0                        [Cancer, 2]
# 127.0                [Cardiovascular, 2]
# 128.0                     [Metabolic, 2]
# 129.0                          [Bone, 2]
# 130.0                          [Bone, 2]
# 131.0                 [Hematological, 2]
# 132.0                     [Endocrine, 2]
# 133.0               [Ophthamological, 2]
# 134.0                   [Psychiatric, 2]
# 135.0                      [Skeletal, 2]
# 136.0                [Dermatological, 2]
# 137.0                        [Cancer, 2]
# 138.0                     [Metabolic, 2]
# 139.0                     [Metabolic, 2]
# 140.0                      [multiple, 2]
# Name: Disorder class, Length: 99, dtype: object

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# Getting a list of all the nodes' classes, in order
classlist=list(nx.get_node_attributes(diseases,'class').values())

# Creating a dictionary associating each class with a unique integer
classes=set(classlist)
dictionary=dict(zip(classes,range(len(classes))))

# Creating a list of integers corresponding to classes to use for color assignment
classcolors=[dictionary[x] for x in classlist]

plt.rcParams['figure.figsize']=[12,12]

nx.draw_networkx(diseases,
                pos=nx.spring_layout(diseases,weight='weights'),
                cmap=plt.get_cmap('gist_rainbow'),
                node_color=classcolors,
                edge_color='gray',
                node_size=75,
                with_labels=False,
                alpha=.8
                )

plt.axis('off')
plt.show()
