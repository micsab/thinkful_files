# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10, 0.5, 10000)

# Let's make histograms for the two groups

plt.hist(pop1, alpha=0.5, label='Population 1')
plt.hist(pop2, alpha=0.5, label='Population 2')
plt.legend(loc='upper right')
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.5, label='sample 1')
plt.hist(sample2, alpha=.5, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

# Computer the difference between the two sample means
diff = sample2.mean() - sample1.mean()
print(diff)
# Out:
# 1.92
# 4.9
# 1.1461239025515524
# 1.7578395831246947
# 2.9800000000000004

# %% [markdown]
# 1. I think that by increasing the sample size the diff between the two means will approach closer to 3 while decreasing the sample will lower it.  I also think that the standard deviations will increase as the sample size decreases.

# %%
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=.5, label='sample 1')
plt.hist(sample2, alpha=.5, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

# Computer the difference between the two sample means
diff = sample2.mean() - sample1.mean()
print(diff)
# Out:
# 1.97
# 4.953
# 1.2550298801223818
# 1.5648613357099728
# 2.9830000000000005

# %%
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=.5, label='sample 1')
plt.hist(sample2, alpha=.5, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

# Computer the difference between the two sample means
diff = sample2.mean() - sample1.mean()
print(diff)
# Out:
# 1.8
# 5.3
# 1.4000000000000001
# 1.268857754044952
# 3.5

# %% [markdown]
# 2. Changing the p-value in group 1 from 0.3 to 0.4 will lower the sample p-value

# %%
pop1 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10, 0.5, 10000)

# Let's make histograms for the two groups

plt.hist(pop1, alpha=0.5, label='Population 1')
plt.hist(pop2, alpha=0.5, label='Population 2')
plt.legend(loc='upper right')
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.5, label='sample 1')
plt.hist(sample2, alpha=.5, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=5.3240183708574, pvalue=2.8137732086145216e-07)

# %% [markdown]
# 3.

# %%
pop1 = np.random.power(10., 10000)
pop2 = np.random.power(20., 10000)

# Let's make histograms for the two groups

plt.hist(pop1, alpha=0.5, label='Population 1')
plt.hist(pop2, alpha=0.5, label='Population 2')
plt.legend(loc='upper right')
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.5, label='sample 1')
plt.hist(sample2, alpha=.5, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

# Computer the difference between the two sample means
diff = sample2.mean() - sample1.mean()
print(diff)
# Out:
# 0.9098442842513131
# 0.9346352946178175
# 0.08097426017179088
# 0.065456071983342
# 0.02479101036650433

# %%
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=2.369030100551251, pvalue=0.01883957350527161)
