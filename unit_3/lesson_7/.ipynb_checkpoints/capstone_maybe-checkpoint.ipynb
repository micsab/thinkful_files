# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Training Data
players = pd.read_csv('Players.csv')
player_data = pd.read_csv('player_data.csv')
season_stats = pd.read_csv('Seasons_Stats.csv')
season_stats = season_stats.drop(['blanl', 'blank2', 'Unnamed: 0'], axis=1)
season_stats = season_stats[season_stats.Tm.str.contains('TOT') == False]
# Maybe use this for classification?
# season_stats['MVP_Candidate'] = np.where(season_stats['MVPSHARES'] > 0, 1, 0)
season_stats['Player'] = season_stats['Player'].astype(str).str.replace('*', '')
season_stats['PPG'] = season_stats['PTS'] / season_stats['G']
season_stats['ASTPG'] = season_stats['AST'] / season_stats['G']
season_stats['STLPG'] = season_stats['STL'] / season_stats['G']
season_stats['BLKPG'] = season_stats['BLK'] / season_stats['G']
season_stats['PFPG'] = season_stats['PF'] / season_stats['G']
season_stats['TRPG'] = season_stats['TRB'] / season_stats['G']
# season_stats['ORPG'] = season_stats['ORB'] / season_stats['G']
# season_stats['DRPG'] = season_stats['DRB'] / season_stats['G']
season_stats['MPPG'] = season_stats['MP'] / season_stats['G']
season_stats = season_stats.drop(['PTS', 'AST', 'STL', 'BLK', 'PF', 'TRB', 'ORB', 'DRB', 'MP',
                                 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA'], axis=1)
season_stats = season_stats[season_stats['G'] >= 41.0]
season_stats = season_stats[season_stats['MPPG'] >= 25.0]
season_stats = season_stats.dropna()

# %%
season_stats.head()
# Out:
#         Year Decade          Player Pos   Age   Tm     G    GS   PER    TS%  \
# 5730  1980.0   80's  Tiny Archibald  PG  31.0  BOS  80.0  80.0  15.3  0.574
# 5748  1980.0   80's      Larry Bird  PF  23.0  BOS  82.0  82.0  20.5  0.538
# 5802  1980.0   80's     Dave Cowens   C  31.0  BOS  66.0  55.0  14.8  0.477
# 5835  1980.0   80's      Chris Ford  SG  31.0  BOS  73.0  73.0  13.0  0.537
# 6091  1981.0   80's  Tiny Archibald  PG  32.0  BOS  80.0  72.0  14.3  0.582
#
#        3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS  \
# 5730  0.023  0.548   2.3   5.3   3.8  30.2   1.7   0.2  19.7  17.0  5.9  2.9
# 5748  0.098  0.246   8.3  23.6  16.0  18.5   2.3   1.0  14.0  25.3  5.6  5.6
# 5802  0.013  0.131   6.6  20.7  13.8  13.4   1.5   1.6   9.9  20.1  1.9  3.6
# 5835  0.231  0.161   4.1   5.4   4.8  13.5   2.5   0.7  12.2  16.2  2.9  2.6
# 6091  0.012  0.547   1.5   5.4   3.6  28.5   1.3   0.4  21.8  17.5  4.6  2.3
#
#         WS  WS/48  OBPM  DBPM  BPM  VORP    FG%    3P%    2P%   eFG%    FT%  \
# 5730   8.9  0.148   1.1  -1.1  0.0   1.5  0.482  0.222  0.488  0.485  0.830
# 5748  11.2  0.182   2.7   2.6  5.3   5.4  0.474  0.406  0.481  0.494  0.836
# 5802   5.4  0.121  -0.7   2.0  1.4   1.8  0.453  0.083  0.458  0.453  0.779
# 5835   5.6  0.126   1.4   0.8  2.2   2.2  0.465  0.427  0.477  0.515  0.754
# 6091   6.9  0.118   0.4  -1.6 -1.3   0.5  0.499  0.000  0.505  0.499  0.816
#
#         TOV  MVPSHARES  MVP        PPG     ASTPG     STLPG     BLKPG  \
# 5730  242.0      0.000    0  14.137500  8.387500  1.325000  0.125000
# 5748  263.0      0.000    0  21.280488  4.512195  1.743902  0.646341
# 5802  108.0      0.000    0  14.242424  3.121212  1.045455  0.924242
# 5835  105.0      0.000    0  11.178082  2.945205  1.520548  0.369863
# 6091  265.0      0.046    0  13.825000  7.725000  0.937500  0.225000
#
#           PFPG       TRPG       MPPG
# 5730  2.725000   2.462500  35.800000
# 5748  3.402439  10.390244  36.036585
# 5802  3.272727   8.090909  32.712121
# 5835  2.438356   2.479452  28.972603
# 6091  2.512500   2.200000  35.250000

# %%
mvp = season_stats[season_stats['MVP'] == 1]
mvp['Decade']
mvp_80 = mvp[(mvp['Year'] >= 1980.0) & (mvp['Year'] < 1990.0)]
mvp_90 = mvp[(mvp['Year'] >= 1990.0) & (mvp['Year'] < 2000.0)]
mvp_00 = mvp[(mvp['Year'] >= 2000.0) & (mvp['Year'] < 2010.0)]
mvp_10 = mvp[mvp['Year'] >= 2010.0]

# %%
ax = sns.barplot(x='Decade', y='PER', hue='Pos', data=mvp)

# %%
season_stats[season_stats['Player'] == 'Kareem Abdul-Jabbar']
# Out:
#         Year               Player Pos   Age   Tm     G    GS   PER    TS%  \
# 6449  1982.0  Kareem Abdul-Jabbar   C  34.0  LAL  76.0  76.0  23.4  0.608
# 6823  1983.0  Kareem Abdul-Jabbar   C  35.0  LAL  79.0  79.0  23.6  0.619
# 7215  1984.0  Kareem Abdul-Jabbar   C  36.0  LAL  80.0  80.0  21.3  0.608
# 7559  1985.0  Kareem Abdul-Jabbar   C  37.0  LAL  79.0  79.0  22.9  0.628
# 7922  1986.0  Kareem Abdul-Jabbar   C  38.0  LAL  79.0  79.0  22.7  0.603
# 8302  1987.0  Kareem Abdul-Jabbar   C  39.0  LAL  78.0  78.0  17.9  0.597
# 8681  1988.0  Kareem Abdul-Jabbar   C  40.0  LAL  80.0  80.0  15.8  0.570
#
#        3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS  \
# 6449  0.002  0.340   7.3  19.1  13.4  11.9   1.1   4.1  13.3  25.6  6.9  3.9
# 6823  0.002  0.302   7.6  17.6  12.8  10.8   1.1   3.5  12.6  24.6  8.0  2.9
# 7215  0.001  0.318   7.8  16.8  12.7  11.5   1.0   2.9  13.5  25.1  5.9  3.1
# 7559  0.001  0.327   7.7  18.2  13.5  13.1   1.1   3.3  12.5  24.3  7.6  3.6
# 7922  0.001  0.328   6.0  14.2  10.3  15.7   1.2   2.7  11.7  26.6  7.6  3.2
# 8302  0.003  0.345   7.4  15.8  11.9  11.6   0.9   2.2  14.0  22.1  4.5  3.0
# 8681  0.001  0.298   6.1  16.9  11.7   8.4   1.0   2.2  13.5  21.4  2.6  2.7
#
#         WS  WS/48  OBPM  DBPM  BPM  VORP    FG%    3P%    2P%   eFG%    FT%  \
# 6449  10.7  0.192   2.9   1.4  4.3   4.2  0.579  0.000  0.580  0.579  0.706
# 6823  10.9  0.205   3.6   0.3  3.8   3.8  0.588  0.000  0.589  0.588  0.749
# 7215   8.9  0.163   2.4   0.4  2.8   3.2  0.578  0.000  0.579  0.578  0.723
# 7559  11.2  0.204   3.6   1.3  4.9   4.6  0.599  0.000  0.600  0.599  0.732
# 7922  10.8  0.197   3.7   0.8  4.5   4.3  0.564  0.000  0.565  0.564  0.765
# 8302   7.5  0.148   1.2   0.4  1.6   2.2  0.564  0.333  0.565  0.564  0.714
# 8681   5.3  0.111  -0.8   0.2 -0.6   0.8  0.532  0.000  0.532  0.532  0.762
#
#         TOV  MVPSHARES  MVP        PPG     ASTPG     STLPG     BLKPG  \
# 6449  230.0      0.045    0  23.921053  2.960526  0.828947  2.723684
# 6823  200.0      0.020    0  21.797468  2.531646  0.772152  2.151899
# 7215  221.0      0.201    0  21.462500  2.637500  0.687500  1.787500
# 7559  197.0      0.264    0  21.962025  3.151899  0.797468  2.050633
# 7922  203.0      0.173    0  23.367089  3.544304  0.848101  1.645570
# 8302  186.0      0.000    0  17.512821  2.602564  0.628205  1.243590
# 8681  159.0      0.000    0  14.562500  1.687500  0.600000  1.150000
#
#           PFPG      TRPG       MPPG
# 6449  2.947368  8.671053  35.223684
# 6823  2.784810  7.493671  32.329114
# 7215  2.637500  7.337500  32.775000
# 7559  3.012658  7.873418  33.291139
# 7922  3.139241  6.050633  33.278481
# 8302  3.141026  6.705128  31.294872
# 8681  2.700000  5.975000  28.850000

# %%
# Test Data
season_2018 = pd.read_csv('2018_season.csv')
season_2018 = season_2018.drop(['blanl', 'blank2', 'Unnamed: 0'], axis=1)
season_2018 = season_2018[season_2018.Tm.str.contains('TOT') == False]
# Maybe use this for classification?
# season_2018['MVP_Candidate'] = np.where(season_2018['MVPSHARES'] > 0, 1, 0)
season_2018['Player'] = season_2018['Player'].astype(str).str.replace('*', '')
season_2018['PPG'] = season_2018['PTS'] / season_2018['G']
season_2018['ASTPG'] = season_2018['AST'] / season_2018['G']
season_2018['STLPG'] = season_2018['STL'] / season_2018['G']
season_2018['BLKPG'] = season_2018['BLK'] / season_2018['G']
season_2018['PFPG'] = season_2018['PF'] / season_2018['G']
season_2018['TRPG'] = season_2018['TRB'] / season_2018['G']
# season_2018['ORPG'] = season_2018['ORB'] / season_2018['G']
# season_2018['DRPG'] = season_2018['DRB'] / season_2018['G']
season_2018['MPPG'] = season_2018['MP'] / season_2018['G']
season_2018 = season_2018.drop(['PTS', 'AST', 'STL', 'BLK', 'PF', 'TRB', 'ORB', 'DRB', 'MP',
                                 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA'], axis=1)
season_2018 = season_2018[season_2018['G'] >= 41.0]
season_2018 = season_2018[season_2018['MPPG'] >= 25.0]
season_2018 = season_2018.dropna()

# %%
corrmap = season_stats.corr().abs()
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.heatmap(corrmap)

# %%
from sklearn.model_selection import train_test_split
y = season_stats['MVPSHARES']
X = season_stats.drop(['Tm', 'Pos', 'MVPSHARES'], axis=1)


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
# Create correlation matrix
corr_matrix = X.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Drop features 
X.drop(X.columns[to_drop], axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-142-e5b7c4e0dcf1> in <module>()
#       1 # Drop features
# ----> 2 X.drop(X.columns[to_drop], axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
high_corr_var = np.where(corrmap>0.8)
high_corr_var=[(corrmap.index[x],corrmap.columns[y]) 
               for x,y in zip(*high_corr_var) if x!=y and x<y]
high_corr_var
# Out:
# [('PER', 'WS'),
#  ('PER', 'WS/48'),
#  ('TS%', 'eFG%'),
#  ('ORB%', 'TRB%'),
#  ('ORB%', 'TRPG'),
#  ('DRB%', 'TRB%'),
#  ('DRB%', 'TRPG'),
#  ('TRB%', 'TRPG'),
#  ('AST%', 'ASTPG'),
#  ('STL%', 'STLPG'),
#  ('BLK%', 'BLKPG'),
#  ('USG%', 'PPG'),
#  ('OWS', 'WS'),
#  ('OWS', 'WS/48'),
#  ('OWS', 'OBPM'),
#  ('WS', 'WS/48'),
#  ('WS', 'BPM'),
#  ('WS', 'VORP'),
#  ('WS/48', 'BPM'),
#  ('WS/48', 'VORP'),
#  ('BPM', 'VORP'),
#  ('FG%', '2P%'),
#  ('2P%', 'eFG%')]

# %%
from sklearn.ensemble import RandomForestRegressor
X_train = X_train.drop(['Player'], axis=1)

rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
importance = pd.DataFrame()
importance['features'] = X_train.columns
importance['scores'] = rf.feature_importances_

importance.sort_values('scores', ascending=False).head()
# Out:
#    features    scores
# 18       WS  0.367853
# 4       PER  0.137959
# 15     USG%  0.049620
# 19    WS/48  0.047361
# 17      DWS  0.038848

# %%
rf.score(X_test.drop(['Player'], axis=1),y_test)
# Out:
# 0.719384747845982

# %%
test_pred = rf.predict(season_2018.drop(['Player', 'Tm', 'Pos', 'MVPSHARES'], axis=1))
test_results = pd.DataFrame(season_2018.Player)
test_results['score'] = test_pred
test_results['Year'] = season_2018['Year']
test_results['Share'] = season_2018['MVPSHARES']

# %%
test_results.sort_values('score', ascending=False)
# Out:
#                       Player     score  Year  Share
# 232             James Harden  0.500957  2018  0.955
# 303             LeBron James  0.474413  2018  0.731
# 148            Anthony Davis  0.302861  2018  0.441
# 625        Russell Westbrook  0.242373  2018  0.075
# 146            Stephen Curry  0.196293  2018  0.005
# 93              Jimmy Butler  0.192350  2018  0.005
# 369           Damian Lillard  0.175719  2018  0.205
# 591       Karl-Anthony Towns  0.144144  2018  0.000
# 103             Clint Capela  0.136462  2018  0.000
# 488               Chris Paul  0.116861  2018  0.000
# 15     Giannis Antetokounmpo  0.102491  2018  0.074
# 171             Kevin Durant  0.076661  2018  0.065
# 630         Hassan Whiteside  0.072306  2018  0.000
# 292             Kyrie Irving  0.063634  2018  0.000
# 336              Enes Kanter  0.059277  2018  0.000
# 6          LaMarcus Aldridge  0.057805  2018  0.006
# 168           Andre Drummond  0.048267  2018  0.000
# 324             Nikola Jokic  0.036456  2018  0.000
# 134         DeMarcus Cousins  0.031798  2018  0.000
# 472           Victor Oladipo  0.030444  2018  0.002
# 177              Joel Embiid  0.019627  2018  0.004
# 554              Ben Simmons  0.006033  2018  0.000
# 375               Kevin Love  0.005123  2018  0.000
# 376               Kyle Lowry  0.005099  2018  0.000
# 612             Kemba Walker  0.003818  2018  0.000
# 2               Steven Adams  0.003200  2018  0.000
# 544          Dennis Schroder  0.002366  2018  0.000
# 539         D'Angelo Russell  0.002339  2018  0.000
# 65              Devin Booker  0.001954  2018  0.000
# 637             Lou Williams  0.001585  2018  0.000
# ..                       ...       ...   ...    ...
# 300             Josh Jackson  0.000019  2018  0.000
# 338   Michael Kidd-Gilchrist  0.000019  2018  0.000
# 349               Kyle Kuzma  0.000019  2018  0.000
# 365             Caris LeVert  0.000019  2018  0.000
# 287           Ersan Ilyasova  0.000019  2018  0.000
# 374              Robin Lopez  0.000019  2018  0.000
# 285           Andre Iguodala  0.000019  2018  0.000
# 284              Serge Ibaka  0.000019  2018  0.000
# 387          Lauri Markkanen  0.000019  2018  0.000
# 391          Wesley Matthews  0.000019  2018  0.000
# 272  Rondae Hollis-Jefferson  0.000019  2018  0.000
# 270           Justin Holiday  0.000019  2018  0.000
# 262              Buddy Hield  0.000019  2018  0.000
# 222              Danny Green  0.000019  2018  0.000
# 136             Allen Crabbe  0.000019  2018  0.000
# 141              Jae Crowder  0.000019  2018  0.000
# 176          Wayne Ellington  0.000019  2018  0.000
# 194             Yogi Ferrell  0.000019  2018  0.000
# 198             De'Aaron Fox  0.000019  2018  0.000
# 476              Kelly Oubre  0.000019  2018  0.000
# 225           JaMychal Green  0.000019  2018  0.000
# 433          Markieff Morris  0.000019  2018  0.000
# 432            Marcus Morris  0.000019  2018  0.000
# 429            E'Twaun Moore  0.000019  2018  0.000
# 291           Brandon Ingram  0.000019  2018  0.000
# 255              John Henson  0.000019  2018  0.000
# 532              Rajon Rondo  0.000019  2018  0.000
# 392         Luc Mbah a Moute  0.000019  2018  0.000
# 316            James Johnson  0.000019  2018  0.000
# 358             Courtney Lee  0.000019  2018  0.000
#
# [148 rows x 4 columns]

# %%
results = pd.DataFrame()
results['rf_score'] = rf.predict(X.drop(['Player'], axis=1))
results['Player'] = season_stats['Player']
results['Year'] = season_stats['Year']
results['MVPSHARE'] = season_stats['MVPSHARES']
results_2016 = results[results['Year'] == 2016.0]

# %%
importance = pd.DataFrame()
importance['features'] = X_train.columns
importance['scores'] = rf.feature_importances_

importance.sort_values('scores', ascending=False).head(25)
# Out:
#    features    scores
# 18       WS  0.367853
# 4       PER  0.137959
# 15     USG%  0.049620
# 19    WS/48  0.047361
# 17      DWS  0.038848
# 30      PPG  0.028058
# 34     PFPG  0.025290
# 7       FTr  0.022562
# 23     VORP  0.020107
# 22      BPM  0.015585
# 16      OWS  0.015223
# 29      TOV  0.014971
# 5       TS%  0.014849
# 1       Age  0.013770
# 28      FT%  0.012680
# 0      Year  0.012517
# 27     eFG%  0.012024
# 25      3P%  0.011424
# 36     MPPG  0.011096
# 21     DBPM  0.010428
# 31    ASTPG  0.010257
# 8      ORB%  0.009009
# 11     AST%  0.008442
# 26      2P%  0.008246
# 14     TOV%  0.007410

# %%
# Out:
# 3.3578604712815815e-05

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
print('Coefficients: \n', regr.coef_)
print('Intercept: \n', regr.intercept_)
print('Score? \n', regr.score(X_test, y_test))
# Out:
# Coefficients:
#  [ 2.44137144e-04 -8.55058658e-05 -2.39700560e-03 -6.23910303e-05
#   3.18442949e-03 -1.57070666e+00 -2.62999800e-02  6.45775109e-02
#  -2.17929570e-02 -1.91457149e-02  3.87837942e-02 -6.51875478e-04
#   2.36963460e-02 -1.91300882e-02  3.39035446e-03 -4.71790649e-03
#   3.17676282e-02  1.93219512e-02 -6.91815731e-03 -4.30065614e-01
#  -5.56022032e-02 -4.03594575e-02  2.72285914e-02  4.50355316e-02
#  -4.12745489e-01 -3.10863766e-02  5.62736152e-02  1.13016105e+00
#   5.99447786e-02  1.47649686e-04  1.19801491e-02  1.00749275e-03
#  -5.81792310e-02  3.48619758e-02 -9.12502190e-03 -1.27176731e-03
#  -1.10373758e-02]
# Intercept:
#  0.21916093803892298
# Score?
#  0.4489810629108056

# %%
mvps = season_stats[season_stats['MVPSHARES'] > 0]
not_mvps = season_stats[season_stats['MVPSHARES'] == 0]

fig, ax = plt.subplots()
sns.distplot(not_mvps['PPG'], ax=ax)
sns.distplot(mvps['PPG'], ax=ax)

# %%
fig, ax = plt.subplots()
sns.distplot(not_mvps['BLKPG'], ax=ax)
sns.distplot(mvps['BLKPG'], ax=ax)

# %%
sns.distplot(mvps['MVPSHARES'])

# %%
season_2018 = pd.read_csv('2018_season.csv')

# %%
season_2018.head()
# Out:
#    Unnamed: 0  Year         Player Pos  Age   Tm   G  GS    MP   PER    TS%  \
# 0         NaN  2018   Alex Abrines  SG   24  OKC  75   8  1134   9.0  0.567
# 1         NaN  2018     Quincy Acy  PF   27  BRK  70   8  1359   8.2  0.525
# 2         NaN  2018   Steven Adams   C   24  OKC  76  76  2487  20.6  0.630
# 3         NaN  2018    Bam Adebayo   C   20  MIA  69  19  1368  15.7  0.570
# 4         NaN  2018  Arron Afflalo  SG   32  ORL  53   3   682   5.8  0.516
#
#     3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  blanl  OWS  \
# 0  0.759  0.158   2.5   8.9   5.6   3.4   1.7   0.6   7.4  12.7      0  1.3
# 1  0.800  0.164   3.1  17.0  10.0   6.0   1.2   1.6  13.3  14.4      0 -0.1
# 2  0.003  0.402  16.6  13.9  15.3   5.5   1.8   2.8  13.2  16.7      0  6.7
# 3  0.021  0.526   9.7  21.6  15.6  11.0   1.2   2.5  13.6  15.9      0  2.3
# 4  0.432  0.160   0.6  10.1   5.3   6.2   0.3   1.1  10.8  12.5      0 -0.1
#
#    DWS   WS  WS/48  blank2  OBPM  DBPM  BPM  VORP   FG  FGA    FG%   3P  3PA  \
# 0  1.0  2.2  0.094       0  -0.5  -1.7 -2.2  -0.1  115  291  0.395   84  221
# 1  1.1  1.0  0.036       0  -2.0  -0.2 -2.2  -0.1  130  365  0.356  102  292
# 2  3.0  9.7  0.187       0   2.2   1.1  3.3   3.3  448  712  0.629    0    2
# 3  1.9  4.2  0.148       0  -1.6   1.8  0.2   0.8  174  340  0.512    0    7
# 4  0.2  0.1  0.009       0  -4.1  -1.8 -5.8  -0.7   65  162  0.401   27   70
#
#      3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  TRB  AST  STL  \
# 0  0.380   31   70  0.443  0.540   39   46  0.848   26   88  114   28   38
# 1  0.349   28   73  0.384  0.496   49   60  0.817   40  217  257   57   33
# 2  0.000  448  710  0.631  0.629  160  286  0.559  384  301  685   88   92
# 3  0.000  174  333  0.523  0.512  129  179  0.721  118  263  381  101   32
# 4  0.386   38   92  0.413  0.485   22   26  0.846    4   62   66   30    4
#
#    BLK  TOV   PF   PTS  MVPSHARES
# 0    8   25  124   353        0.0
# 1   29   60  149   411        0.0
# 2   78  128  215  1056        0.0
# 3   41   66  138   477        0.0
# 4    9   21   56   179        0.0
