# %%
import scrapy
from scrapy.crawler import CrawlerProcess


class WikiSpider(scrapy.Spider):
    name = "WS"
    
    # Here is where we insert our API call.
    start_urls = [
        'https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect'
        ]

    # Identifying the information we want from the query response and extracting it using xpath.
    def parse(self, response):
        for item in response.xpath('//lh'):
            # The ns code identifies the type of page the link comes from.  '0' means it is a Wikipedia entry.
            # Other codes indicate links from 'Talk' pages, etc.  Since we are only interested in entries, we filter:
            if item.xpath('@ns').extract_first() == '0':
                yield {
                    'title': item.xpath('@title').extract_first() 
                    }
        # Getting the information needed to continue to the next ten entries.
        next_page = response.xpath('continue/@lhcontinue').extract_first()
        
        # Recursively calling the spider to process the next ten entries, if they exist.
        if next_page is not None:
            next_page = '{}&lhcontinue={}'.format(self.start_urls[0],next_page)
            yield scrapy.Request(next_page, callback=self.parse)
            
    
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'PythonLinks.json',
    # Note that because we are doing API queries, the robots.txt file doesn't apply to us.
    'ROBOTSTXT_OBEY': False,
    'USER_AGENT': 'ThinkfulDataScienceBootcampCrawler (thinkful.com)',
    'AUTOTHROTTLE_ENABLED': True,
    'HTTPCACHE_ENABLED': True,
    'LOG_ENABLED': True,
    # We use CLOSESPIDER_PAGECOUNT to limit our scraper to the first 100 links.    
    'CLOSESPIDER_PAGECOUNT' : 10
})
                                         

# Starting the crawler with our spider.
process.crawl(WikiSpider)
process.start()
print('First 100 links extracted!')
# Out:
# 2018-11-26 16:49:13 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-11-26 16:49:13 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.19.0, Twisted 18.9.0, Python 3.7.0 (default, Jun 29 2018, 20:13:13) - [Clang 9.1.0 (clang-902.0.39.2)], pyOpenSSL 18.0.0 (OpenSSL 1.1.0j  20 Nov 2018), cryptography 2.4.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-11-26 16:49:13 [scrapy.crawler] INFO: Overridden settings: {'AUTOTHROTTLE_ENABLED': True, 'CLOSESPIDER_PAGECOUNT': 10, 'FEED_FORMAT': 'json', 'FEED_URI': 'PythonLinks.json', 'HTTPCACHE_ENABLED': True, 'USER_AGENT': 'ThinkfulDataScienceBootcampCrawler (thinkful.com)'}
# 2018-11-26 16:49:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.closespider.CloseSpider',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2018-11-26 16:49:14 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats',
#  'scrapy.downloadermiddlewares.httpcache.HttpCacheMiddleware']
# 2018-11-26 16:49:14 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-11-26 16:49:14 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-11-26 16:49:14 [scrapy.core.engine] INFO: Spider opened
# 2018-11-26 16:49:14 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-11-26 16:49:14 [scrapy.extensions.httpcache] DEBUG: Using filesystem cache storage in .scrapy/httpcache
# 2018-11-26 16:49:14 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6024
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect> (referer: None) ['cached']
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Alberto Giacometti'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Beachcomber (pen name)'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Bob Costas'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Comedy film'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'List of comedians'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Douglas Adams'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Desmond Morris'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'David Bowie'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect>
# {'title': 'Do Not Adjust Your Set'}
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect) ['cached']
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Elvis Presley'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Ennio Morricone'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Cinema of the United Kingdom'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Fawlty Towers'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Federico Fellini'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'George Harrison'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Gilbert and Sullivan'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Graham Chapman'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Hunter S. Thompson'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288>
# {'title': 'Harry Kroto'}
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=9288) ['cached']
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'Ingmar Bergman'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'John Cleese'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'J. K. Rowling'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'John Peel'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'Joke'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'Kate Bush'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': "Monty Python's Life of Brian"}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'Spam (Monty Python)'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626>
# {'title': 'Dead Parrot sketch'}
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=14626) ['cached']
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Cheese Shop sketch'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': "Bruces' Philosophers Song"}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'The Funniest Joke in the World'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'The Spanish Inquisition (Monty Python)'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Michael Palin'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Monty Python and the Holy Grail'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Metasyntactic variable'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Meet the Feebles'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Mad (magazine)'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162>
# {'title': 'Orson Welles'}
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=19162) ['cached']
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Proverb'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Peter Cook'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Python (programming language)'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Peter Sellers'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Pembroke College, Cambridge'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Roman Polanski'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'René Magritte'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Sean Connery'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'Sam Peckinpah'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529>
# {'title': 'South Park'}
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=23529) ['cached']
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'Simon the Sorcerer'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'Spam (food)'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'Superman'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'Spike Milligan'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'Surrealism'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'The Goon Show'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'Terry Gilliam'}
# 2018-11-26 16:49:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341>
# {'title': 'The Stranglers'}
# 2018-11-26 16:49:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=28341) ['cached']
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'The Residents'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'The Goodies'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'Traveling Wilburys'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'Clangers'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': '1890s'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'Tristan Tzara'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'Antioch'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'Trondheim'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629>
# {'title': 'Shit'}
# 2018-11-26 16:49:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=30629) ['cached']
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Slapstick'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Michelangelo Antonioni'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Salvador Dalí'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Cameron Diaz'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Walter Mondale'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'The Rime of the Ancient Mariner'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Around the World in Eighty Days'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Max Ernst'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384>
# {'title': 'Andrzej Wajda'}
# 2018-11-26 16:49:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=38384) ['cached']
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Billy Wilder'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Catherine Deneuve'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Beyond the Fringe'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Cunt'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'List of Welsh people'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Downing College, Cambridge'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Dan Aykroyd'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Bernardo Bertolucci'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185>
# {'title': 'Marty Feldman'}
# 2018-11-26 16:49:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610> (referer: https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=45185) ['cached']
# 2018-11-26 16:49:15 [scrapy.core.engine] INFO: Closing spider (closespider_pagecount)
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Sketch comedy'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Terry Jones'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': "I'm Sorry, I'll Read That Again"}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Eric Idle'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Robin Williams'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Tracey Ullman'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Surrealist automatism'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Raymond Queneau'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'André Breton'}
# 2018-11-26 16:49:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/w/api.php?action=query&format=xml&prop=linkshere&titles=Monty_Python&lhprop=title%7Credirect&lhcontinue=51610>
# {'title': 'Tim Brooke-Taylor'}
# 2018-11-26 16:49:15 [scrapy.extensions.feedexport] INFO: Stored json feed (93 items) in: PythonLinks.json
# 2018-11-26 16:49:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 5667,
#  'downloader/request_count': 10,
#  'downloader/request_method_count/GET': 10,
#  'downloader/response_bytes': 14564,
#  'downloader/response_count': 10,
#  'downloader/response_status_count/200': 10,
#  'finish_reason': 'closespider_pagecount',
#  'finish_time': datetime.datetime(2018, 11, 27, 0, 49, 15, 492286),
#  'httpcache/hit': 10,
#  'item_scraped_count': 93,
#  'log_count/DEBUG': 105,
#  'log_count/INFO': 8,
#  'memusage/max': 67842048,
#  'memusage/startup': 67842048,
#  'request_depth_max': 10,
#  'response_received_count': 10,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 11,
#  'scheduler/enqueued/memory': 11,
#  'start_time': datetime.datetime(2018, 11, 27, 0, 49, 14, 106810)}
# 2018-11-26 16:49:15 [scrapy.core.engine] INFO: Spider closed (closespider_pagecount)
# First 100 links extracted!

# %%
import pandas as pd
# Checking whether we got data
Monty=pd.read_json('PythonLinks.json', orient='records')
print(Monty.shape)
print(Monty.tail())
