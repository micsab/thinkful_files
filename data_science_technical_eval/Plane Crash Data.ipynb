# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plane_crash = pd.read_csv('plane_crashes_data.csv')
plane_crash.describe()
# Out:
#              month         year       aboard   fatalities
# count  2709.000000  2709.000000  2709.000000  2709.000000
# mean      6.554079  1981.927279    35.817276    25.816537
# std       3.532468    16.709136    54.306779    42.599461
# min       1.000000  1950.000000     0.000000     0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000
# 50%       7.000000  1983.000000    15.000000     9.000000
# 75%      10.000000  1997.000000    44.000000    29.000000
# max      12.000000  2009.000000   644.000000   583.000000

# %%
plane_crash['kill_percent'] = plane_crash.fatalities / plane_crash.aboard

# %%
plane_crash.sort_values(by=['fatalities'], ascending=False).head(5)
# Out:
#       month hour  year                                 location  \
# 1105      3   17  1977                 Tenerife, Canary Islands
# 1439      8   18  1985    Mt. Osutaka, near Ueno Village, Japan
# 2001     11   18  1996                 Near Charkhidadri, India
# 978       3   11  1974                Near Ermenonville, France
# 1434      6    7  1985  AtlantiOcean, 110 miles West of Ireland
#
#                                         operator  \
# 1105            Pan American World Airways / KLM
# 1439                             Japan Air Lines
# 2001  Saudi Arabian Airlines / Kazastan Airlines
# 978                       Turkish Airlines (THY)
# 1434                                   Air India
#
#                                               route  \
# 1105  Tenerife - Las Palmas / Tenerife - Las Palmas
# 1439                                  Tokyo - Osaka
# 2001     New Delhi - Dhahran / Chimkent - New Delhi
# 978                                  Paris - London
# ...

# %%
crash_new = plane_crash[plane_crash['year'] >= 1980]
crash_new.describe()
# Out:
#              month         year      aboard   fatalities  kill_percent
# count  1469.000000  1469.000000  1469.00000  1469.000000   1468.000000
# mean      6.567733  1995.346494    36.87066    24.932607      0.816284
# std       3.486888     8.076045    61.35977    45.951019      0.314999
# min       1.000000  1980.000000     0.00000     0.000000      0.000000
# 25%       3.000000  1989.000000     4.00000     3.000000      0.727273
# 50%       7.000000  1996.000000    11.00000     7.000000      1.000000
# 75%       9.000000  2002.000000    39.00000    22.000000      1.000000
# max      12.000000  2009.000000   524.00000   520.000000      1.000000

# %%
plane_crash.describe()
# Out:
#              month         year       aboard   fatalities
# count  2709.000000  2709.000000  2709.000000  2709.000000
# mean      6.554079  1981.927279    35.817276    25.816537
# std       3.532468    16.709136    54.306779    42.599461
# min       1.000000  1950.000000     0.000000     0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000
# 50%       7.000000  1983.000000    15.000000     9.000000
# 75%      10.000000  1997.000000    44.000000    29.000000
# max      12.000000  2009.000000   644.000000   583.000000

# %%
dead_crash = plane_crash[plane_crash['fatalities'] < 1]
dead_crash.describe()
# Out:
#            month         year      aboard  fatalities  kill_percent
# count  49.000000    49.000000   49.000000        49.0          48.0
# mean    6.367347  1985.285714   93.387755         0.0           0.0
# std     3.308410    16.684574   87.522096         0.0           0.0
# min     1.000000  1953.000000    0.000000         0.0           0.0
# 25%     3.000000  1969.000000   26.000000         0.0           0.0
# 50%     7.000000  1988.000000   76.000000         0.0           0.0
# 75%     8.000000  1998.000000  142.000000         0.0           0.0
# max    12.000000  2009.000000  309.000000         0.0           0.0

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(fatal['fatalities'])

# %%
grouped = plane_crash.groupby('year').aggregate(np.sum)
plt.plot(grouped['fatalities']/grouped['aboard'])
plt.show()

# %%
plane_crash.describe()
# Out:
#              month         year       aboard   fatalities  kill_percent
# count  2709.000000  2709.000000  2709.000000  2709.000000   2708.000000
# mean      6.554079  1981.927279    35.817276    25.816537      0.823132
# std       3.532468    16.709136    54.306779    42.599461      0.308131
# min       1.000000  1950.000000     0.000000     0.000000      0.000000
# 25%       3.000000  1968.000000     5.000000     3.000000      0.750000
# 50%       7.000000  1983.000000    15.000000     9.000000      1.000000
# 75%      10.000000  1997.000000    44.000000    29.000000      1.000000
# max      12.000000  2009.000000   644.000000   583.000000      1.000000

# %%
plane_crash.groupby('month')
